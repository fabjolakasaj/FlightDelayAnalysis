# %% [markdown]
# # Downloading the Dataset
#
# #### This part of the code has been executed only once. It helped me to download the data for each month from 2010 to 2020. I tried different ways to download this dataset but this was the best one even though time consuming. I had the chance to read the menaing of each field and to choose which ones to download. At the same time I noticed that the values of the fields were more accurate in this way than downloading the whole dataset at once.
#
# #### We won't need to run this code anymore

# %% [markdown]
# Here is the LINK where you can find the meaning of each field in this dataset: https://transtats.bts.gov/DL_SelectFields.asp?gnoyr_VQ=FGJ&QO_fu146_anzr=b0-gvzr

# %%
import pandas as pd

# %% [markdown]
# df_2010_january = pd.read_csv(r'C:/Users/STSC/Downloads/290904056_T_ONTIME_REPORTING/290904056_T_ONTIME_REPORTING.csv')
# df_2010_january.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2010_january.to_csv (r'C:/Users/STSC/Desktop/Dataset/2010/january_2010.csv', index = False, header=True)

# %% [markdown]
# df_2011_january = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING/290948635_T_ONTIME_REPORTING.csv')
# df_2011_january.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2011_january.to_csv (r'C:/Users/STSC/Desktop/Dataset/2011/january_2011.csv', index = False, header=True)

# %% [markdown]
# df_2012_january = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING/290948635_T_ONTIME_REPORTING.csv')
# df_2012_january.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2012_january.to_csv (r'C:/Users/STSC/Desktop/Dataset/2012/january_2012.csv', index = False, header=True)

# %% [markdown]
# df_2013_january = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING/290948635_T_ONTIME_REPORTING.csv')
# df_2013_january.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2013_january.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/january_2013.csv', index = False, header=True)

# %% [markdown]
# df_2014_january = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2014_january.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2014_january.to_csv (r'C:/Users/STSC/Desktop/Dataset/2014/january_2014.csv', index = False, header=True)

# %% [markdown]
# df_2015_january = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2015_january.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2015_january.to_csv (r'C:/Users/STSC/Desktop/Dataset/2015/january_2015.csv', index = False, header=True)

# %% [markdown]
# df_2016_january = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING/290948635_T_ONTIME_REPORTING.csv')
# df_2016_january.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2016_january.to_csv (r'C:/Users/STSC/Desktop/Dataset/2016/january_2016.csv', index = False, header=True)

# %% [markdown]
# df_2017_january = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2017_january.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2017_january.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/january_2017.csv', index = False, header=True)

# %% [markdown]
# df_2018_january = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2018_january.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2018_january.to_csv (r'C:/Users/STSC/Desktop/Dataset/2018/january_2018.csv', index = False, header=True)

# %% [markdown]
# df_2019_january = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (3)/290948635_T_ONTIME_REPORTING.csv')
# df_2019_january.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2019_january.to_csv (r'C:/Users/STSC/Desktop/Dataset/2019/january_2019.csv', index = False, header=True)

# %% [markdown]
# df_2020_january = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (4)/290948635_T_ONTIME_REPORTING.csv')
# df_2020_january.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2020_january.to_csv (r'C:/Users/STSC/Desktop/Dataset/2020/january_2020.csv', index = False, header=True)

# %% [markdown]
# #df_2010_february = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING/290948635_T_ONTIME_REPORTING.csv')
# #df_2010_february.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# #df_2010_february.to_csv (r'C:/Users/STSC/Desktop/Dataset/2010/february_2010.csv', index = False, header=True)
#
# df_2011_february = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2011_february.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2011_february.to_csv (r'C:/Users/STSC/Desktop/Dataset/2011/february_2011.csv', index = False, header=True)
#
# df_2012_february = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2012_february.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2012_february.to_csv (r'C:/Users/STSC/Desktop/Dataset/2012/february_2012.csv', index = False, header=True)
#
# df_2013_february = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (3)/290948635_T_ONTIME_REPORTING.csv')
# df_2013_february.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2013_february.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/february_2013.csv', index = False, header=True)
#
# df_2014_february = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (4)/290948635_T_ONTIME_REPORTING.csv')
# df_2014_february.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2014_february.to_csv (r'C:/Users/STSC/Desktop/Dataset/2014/february_2014.csv', index = False, header=True)
#
# df_2015_february = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (5)/290948635_T_ONTIME_REPORTING.csv')
# df_2015_february.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2015_february.to_csv (r'C:/Users/STSC/Desktop/Dataset/2015/february_2015.csv', index = False, header=True)
#
# df_2016_february = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (6)/290948635_T_ONTIME_REPORTING.csv')
# df_2016_february.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2016_february.to_csv (r'C:/Users/STSC/Desktop/Dataset/2016/february_2016.csv', index = False, header=True)
#
# df_2017_february = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (7)/290948635_T_ONTIME_REPORTING.csv')
# df_2017_february.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2017_february.to_csv (r'C:/Users/STSC/Desktop/Dataset/2017/february_2017.csv', index = False, header=True)
#
# df_2018_february = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (8)/290948635_T_ONTIME_REPORTING.csv')
# df_2018_february.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2018_february.to_csv (r'C:/Users/STSC/Desktop/Dataset/2018/february_2018.csv', index = False, header=True)
#
# df_2019_february = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (9)/290948635_T_ONTIME_REPORTING.csv')
# df_2019_february.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2019_february.to_csv (r'C:/Users/STSC/Desktop/Dataset/2019/february_2019.csv', index = False, header=True)
#
# df_2020_february = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (10)/290948635_T_ONTIME_REPORTING.csv')
# df_2020_february.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2020_february.to_csv (r'C:/Users/STSC/Desktop/Dataset/2020/february_2020.csv', index = False, header=True)

# %% [markdown]
# df_2011_march = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2011_march.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2011_march.to_csv (r'C:/Users/STSC/Desktop/Dataset/2011/march_2011.csv', index = False, header=True)
#
# df_2012_march = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2012_march.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2012_march.to_csv (r'C:/Users/STSC/Desktop/Dataset/2012/march_2012.csv', index = False, header=True)
#
# df_2013_march = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (3)/290948635_T_ONTIME_REPORTING.csv')
# df_2013_march.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2013_march.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/march_2013.csv', index = False, header=True)
#
# df_2014_march = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (4)/290948635_T_ONTIME_REPORTING.csv')
# df_2014_march.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2014_march.to_csv (r'C:/Users/STSC/Desktop/Dataset/2014/march_2014.csv', index = False, header=True)
#
# df_2015_march = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (5)/290948635_T_ONTIME_REPORTING.csv')
# df_2015_march.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2015_march.to_csv (r'C:/Users/STSC/Desktop/Dataset/2015/march_2015.csv', index = False, header=True)
#
# df_2016_march = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (6)/290948635_T_ONTIME_REPORTING.csv')
# df_2016_march.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2016_march.to_csv (r'C:/Users/STSC/Desktop/Dataset/2016/march_2016.csv', index = False, header=True)
#
# df_2017_march = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (7)/290948635_T_ONTIME_REPORTING.csv')
# df_2017_march.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2017_march.to_csv (r'C:/Users/STSC/Desktop/Dataset/2017/march_2017.csv', index = False, header=True)
#
# df_2018_march = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (8)/290948635_T_ONTIME_REPORTING.csv')
# df_2018_march.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2018_march.to_csv (r'C:/Users/STSC/Desktop/Dataset/2018/march_2018.csv', index = False, header=True)
#
# df_2019_march = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (9)/290948635_T_ONTIME_REPORTING.csv')
# df_2019_march.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2019_march.to_csv (r'C:/Users/STSC/Desktop/Dataset/2019/march_2019.csv', index = False, header=True)
#
# df_2020_march = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (10)/290948635_T_ONTIME_REPORTING.csv')
# df_2020_march.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2020_march.to_csv (r'C:/Users/STSC/Desktop/Dataset/2020/march_2020.csv', index = False, header=True)

# %% [markdown]
# df_2011_april = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2011_april.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2011_april.to_csv (r'C:/Users/STSC/Desktop/Dataset/2011/april_2011.csv', index = False, header=True)
#
# df_2012_april = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2012_april.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2012_april.to_csv (r'C:/Users/STSC/Desktop/Dataset/2012/april_2012.csv', index = False, header=True)
#
# df_2013_april = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (3)/290948635_T_ONTIME_REPORTING.csv')
# df_2013_april.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2013_april.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/april_2013.csv', index = False, header=True)
#
# df_2014_april = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (4)/290948635_T_ONTIME_REPORTING.csv')
# df_2014_april.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2014_april.to_csv (r'C:/Users/STSC/Desktop/Dataset/2014/april_2014.csv', index = False, header=True)
#
# df_2015_april = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (5)/290948635_T_ONTIME_REPORTING.csv')
# df_2015_april.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2015_april.to_csv (r'C:/Users/STSC/Desktop/Dataset/2015/april_2015.csv', index = False, header=True)
#
# df_2016_april = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (6)/290948635_T_ONTIME_REPORTING.csv')
# df_2016_april.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2016_april.to_csv (r'C:/Users/STSC/Desktop/Dataset/2016/april_2016.csv', index = False, header=True)
#
# df_2017_april = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (7)/290948635_T_ONTIME_REPORTING.csv')
# df_2017_april.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2017_april.to_csv (r'C:/Users/STSC/Desktop/Dataset/2017/april_2017.csv', index = False, header=True)
#
# df_2018_april = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (8)/290948635_T_ONTIME_REPORTING.csv')
# df_2018_april.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2018_april.to_csv (r'C:/Users/STSC/Desktop/Dataset/2018/april_2018.csv', index = False, header=True)
#
# df_2019_april = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (9)/290948635_T_ONTIME_REPORTING.csv')
# df_2019_april.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2019_april.to_csv (r'C:/Users/STSC/Desktop/Dataset/2019/april_2019.csv', index = False, header=True)
#
# df_2020_april = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (10)/290948635_T_ONTIME_REPORTING.csv')
# df_2020_april.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2020_april.to_csv (r'C:/Users/STSC/Desktop/Dataset/2020/april_2020.csv', index = False, header=True)

# %% [markdown]
# df_2011_may = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2011_may.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2011_may.to_csv (r'C:/Users/STSC/Desktop/Dataset/2011/may_2011.csv', index = False, header=True)
#
# df_2012_may = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2012_may.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2012_may.to_csv (r'C:/Users/STSC/Desktop/Dataset/2012/may_2012.csv', index = False, header=True)
#
# df_2013_may = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (3)/290948635_T_ONTIME_REPORTING.csv')
# df_2013_may.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2013_may.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/may_2013.csv', index = False, header=True)
#
# df_2014_may = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (4)/290948635_T_ONTIME_REPORTING.csv')
# df_2014_may.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2014_may.to_csv (r'C:/Users/STSC/Desktop/Dataset/2014/may_2014.csv', index = False, header=True)
#
# df_2015_may = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (5)/290948635_T_ONTIME_REPORTING.csv')
# df_2015_may.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2015_may.to_csv (r'C:/Users/STSC/Desktop/Dataset/2015/may_2015.csv', index = False, header=True)
#
# df_2016_may = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (6)/290948635_T_ONTIME_REPORTING.csv')
# df_2016_may.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2016_may.to_csv (r'C:/Users/STSC/Desktop/Dataset/2016/may_2016.csv', index = False, header=True)
#
# df_2017_may = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (7)/290948635_T_ONTIME_REPORTING.csv')
# df_2017_may.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2017_may.to_csv (r'C:/Users/STSC/Desktop/Dataset/2017/may_2017.csv', index = False, header=True)
#
# df_2018_may = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (8)/290948635_T_ONTIME_REPORTING.csv')
# df_2018_may.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2018_may.to_csv (r'C:/Users/STSC/Desktop/Dataset/2018/may_2018.csv', index = False, header=True)
#
# df_2019_may = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (9)/290948635_T_ONTIME_REPORTING.csv')
# df_2019_may.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2019_may.to_csv (r'C:/Users/STSC/Desktop/Dataset/2019/may_2019.csv', index = False, header=True)
#
# df_2020_may = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (10)/290948635_T_ONTIME_REPORTING.csv')
# df_2020_may.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2020_may.to_csv (r'C:/Users/STSC/Desktop/Dataset/2020/may_2020.csv', index = False, header=True)

# %% [markdown]
# df_2011_june = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2011_june.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2011_june.to_csv (r'C:/Users/STSC/Desktop/Dataset/2011/june_2011.csv', index = False, header=True)
#
# df_2012_june = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2012_june.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2012_june.to_csv (r'C:/Users/STSC/Desktop/Dataset/2012/june_2012.csv', index = False, header=True)
#
# df_2013_june = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (3)/290948635_T_ONTIME_REPORTING.csv')
# df_2013_june.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2013_june.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/june_2013.csv', index = False, header=True)
#
# df_2014_june = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (4)/290948635_T_ONTIME_REPORTING.csv')
# df_2014_june.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2014_june.to_csv (r'C:/Users/STSC/Desktop/Dataset/2014/june_2014.csv', index = False, header=True)
#
# df_2015_june = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (5)/290948635_T_ONTIME_REPORTING.csv')
# df_2015_june.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2015_june.to_csv (r'C:/Users/STSC/Desktop/Dataset/2015/june_2015.csv', index = False, header=True)
#
# df_2016_june = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (6)/290948635_T_ONTIME_REPORTING.csv')
# df_2016_june.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2016_june.to_csv (r'C:/Users/STSC/Desktop/Dataset/2016/june_2016.csv', index = False, header=True)
#
# df_2017_june = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (7)/290948635_T_ONTIME_REPORTING.csv')
# df_2017_june.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2017_june.to_csv (r'C:/Users/STSC/Desktop/Dataset/2017/june_2017.csv', index = False, header=True)
#
# df_2018_june = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (8)/290948635_T_ONTIME_REPORTING.csv')
# df_2018_june.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2018_june.to_csv (r'C:/Users/STSC/Desktop/Dataset/2018/june_2018.csv', index = False, header=True)
#
# df_2019_june = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (9)/290948635_T_ONTIME_REPORTING.csv')
# df_2019_june.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2019_june.to_csv (r'C:/Users/STSC/Desktop/Dataset/2019/june_2019.csv', index = False, header=True)
#
# df_2020_june = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (10)/290948635_T_ONTIME_REPORTING.csv')
# df_2020_june.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2020_june.to_csv (r'C:/Users/STSC/Desktop/Dataset/2020/june_2020.csv', index = False, header=True)

# %% [markdown]
# df_2011_july = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2011_july.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2011_july.to_csv (r'C:/Users/STSC/Desktop/Dataset/2011/july_2011.csv', index = False, header=True)
#
# df_2012_july = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2012_july.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2012_july.to_csv (r'C:/Users/STSC/Desktop/Dataset/2012/july_2012.csv', index = False, header=True)
#
# df_2013_july = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (3)/290948635_T_ONTIME_REPORTING.csv')
# df_2013_july.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2013_july.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/july_2013.csv', index = False, header=True)
#
# df_2014_july = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (4)/290948635_T_ONTIME_REPORTING.csv')
# df_2014_july.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2014_july.to_csv (r'C:/Users/STSC/Desktop/Dataset/2014/july_2014.csv', index = False, header=True)
#
# df_2015_july = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (5)/290948635_T_ONTIME_REPORTING.csv')
# df_2015_july.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2015_july.to_csv (r'C:/Users/STSC/Desktop/Dataset/2015/july_2015.csv', index = False, header=True)
#
# df_2016_july = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (6)/290948635_T_ONTIME_REPORTING.csv')
# df_2016_july.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2016_july.to_csv (r'C:/Users/STSC/Desktop/Dataset/2016/july_2016.csv', index = False, header=True)
#
# df_2017_july = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (7)/290948635_T_ONTIME_REPORTING.csv')
# df_2017_july.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2017_july.to_csv (r'C:/Users/STSC/Desktop/Dataset/2017/july_2017.csv', index = False, header=True)
#
# df_2018_july = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (8)/290948635_T_ONTIME_REPORTING.csv')
# df_2018_july.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2018_july.to_csv (r'C:/Users/STSC/Desktop/Dataset/2018/july_2018.csv', index = False, header=True)
#
# df_2019_july = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (9)/290948635_T_ONTIME_REPORTING.csv')
# df_2019_july.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2019_july.to_csv (r'C:/Users/STSC/Desktop/Dataset/2019/july_2019.csv', index = False, header=True)
#
# df_2020_july = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (10)/290948635_T_ONTIME_REPORTING.csv')
# df_2020_july.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2020_july.to_csv (r'C:/Users/STSC/Desktop/Dataset/2020/july_2020.csv', index = False, header=True)

# %% [markdown]
# df_2011_august = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2011_august.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2011_august.to_csv (r'C:/Users/STSC/Desktop/Dataset/2011/august_2011.csv', index = False, header=True)
#
# df_2012_august = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2012_august.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2012_august.to_csv (r'C:/Users/STSC/Desktop/Dataset/2012/august_2012.csv', index = False, header=True)
#
# df_2013_august = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (3)/290948635_T_ONTIME_REPORTING.csv')
# df_2013_august.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2013_august.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/august_2013.csv', index = False, header=True)
#
# df_2014_august = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (4)/290948635_T_ONTIME_REPORTING.csv')
# df_2014_august.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2014_august.to_csv (r'C:/Users/STSC/Desktop/Dataset/2014/august_2014.csv', index = False, header=True)
#
# df_2015_august = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (5)/290948635_T_ONTIME_REPORTING.csv')
# df_2015_august.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2015_august.to_csv (r'C:/Users/STSC/Desktop/Dataset/2015/august_2015.csv', index = False, header=True)
#
# df_2016_august = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (6)/290948635_T_ONTIME_REPORTING.csv')
# df_2016_august.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2016_august.to_csv (r'C:/Users/STSC/Desktop/Dataset/2016/august_2016.csv', index = False, header=True)
#
# df_2017_august = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (7)/290948635_T_ONTIME_REPORTING.csv')
# df_2017_august.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2017_august.to_csv (r'C:/Users/STSC/Desktop/Dataset/2017/august_2017.csv', index = False, header=True)
#
# df_2018_august = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (8)/290948635_T_ONTIME_REPORTING.csv')
# df_2018_august.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2018_august.to_csv (r'C:/Users/STSC/Desktop/Dataset/2018/august_2018.csv', index = False, header=True)
#
# df_2019_august = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (9)/290948635_T_ONTIME_REPORTING.csv')
# df_2019_august.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2019_august.to_csv (r'C:/Users/STSC/Desktop/Dataset/2019/august_2019.csv', index = False, header=True)
#
# df_2020_august = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (10)/290948635_T_ONTIME_REPORTING.csv')
# df_2020_august.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2020_august.to_csv (r'C:/Users/STSC/Desktop/Dataset/2020/august_2020.csv', index = False, header=True)

# %% [markdown]
# df_2011_september = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2011_september.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2011_september.to_csv (r'C:/Users/STSC/Desktop/Dataset/2011/september_2011.csv', index = False, header=True)
#
# df_2012_september = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2012_september.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2012_september.to_csv (r'C:/Users/STSC/Desktop/Dataset/2012/september_2012.csv', index = False, header=True)
#
# df_2013_september = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (3)/290948635_T_ONTIME_REPORTING.csv')
# df_2013_september.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2013_september.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/september_2013.csv', index = False, header=True)
#
# df_2014_september = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (4)/290948635_T_ONTIME_REPORTING.csv')
# df_2014_september.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2014_september.to_csv (r'C:/Users/STSC/Desktop/Dataset/2014/september_2014.csv', index = False, header=True)
#
# df_2015_september = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (5)/290948635_T_ONTIME_REPORTING.csv')
# df_2015_september.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2015_september.to_csv (r'C:/Users/STSC/Desktop/Dataset/2015/september_2015.csv', index = False, header=True)
#
# df_2016_september = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (6)/290948635_T_ONTIME_REPORTING.csv')
# df_2016_september.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2016_september.to_csv (r'C:/Users/STSC/Desktop/Dataset/2016/september_2016.csv', index = False, header=True)
#
# df_2017_september = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (7)/290948635_T_ONTIME_REPORTING.csv')
# df_2017_september.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2017_september.to_csv (r'C:/Users/STSC/Desktop/Dataset/2017/september_2017.csv', index = False, header=True)
#
# df_2018_september = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (8)/290948635_T_ONTIME_REPORTING.csv')
# df_2018_september.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2018_september.to_csv (r'C:/Users/STSC/Desktop/Dataset/2018/september_2018.csv', index = False, header=True)
#
# df_2019_september = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (9)/290948635_T_ONTIME_REPORTING.csv')
# df_2019_september.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2019_september.to_csv (r'C:/Users/STSC/Desktop/Dataset/2019/september_2019.csv', index = False, header=True)
#
# df_2020_september = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (10)/290948635_T_ONTIME_REPORTING.csv')
# df_2020_september.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2020_september.to_csv (r'C:/Users/STSC/Desktop/Dataset/2020/september_2020.csv', index = False, header=True)

# %% [markdown]
# df_2011_october = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2011_october.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2011_october.to_csv (r'C:/Users/STSC/Desktop/Dataset/2011/october_2011.csv', index = False, header=True)
#
# df_2012_october = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2012_october.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2012_october.to_csv (r'C:/Users/STSC/Desktop/Dataset/2012/october_2012.csv', index = False, header=True)
#
# df_2013_october = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (3)/290948635_T_ONTIME_REPORTING.csv')
# df_2013_october.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2013_october.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/october_2013.csv', index = False, header=True)
#
# df_2014_october = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (4)/290948635_T_ONTIME_REPORTING.csv')
# df_2014_october.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2014_october.to_csv (r'C:/Users/STSC/Desktop/Dataset/2014/october_2014.csv', index = False, header=True)
#
# df_2015_october = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (5)/290948635_T_ONTIME_REPORTING.csv')
# df_2015_october.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2015_october.to_csv (r'C:/Users/STSC/Desktop/Dataset/2015/october_2015.csv', index = False, header=True)
#
# df_2016_october = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (6)/290948635_T_ONTIME_REPORTING.csv')
# df_2016_october.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2016_october.to_csv (r'C:/Users/STSC/Desktop/Dataset/2016/october_2016.csv', index = False, header=True)
#
# df_2017_october = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (7)/290948635_T_ONTIME_REPORTING.csv')
# df_2017_october.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2017_october.to_csv (r'C:/Users/STSC/Desktop/Dataset/2017/october_2017.csv', index = False, header=True)
#
# df_2018_october = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (8)/290948635_T_ONTIME_REPORTING.csv')
# df_2018_october.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2018_october.to_csv (r'C:/Users/STSC/Desktop/Dataset/2018/october_2018.csv', index = False, header=True)
#
# df_2019_october = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (9)/290948635_T_ONTIME_REPORTING.csv')
# df_2019_october.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2019_october.to_csv (r'C:/Users/STSC/Desktop/Dataset/2019/october_2019.csv', index = False, header=True)
#
# df_2020_october = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (10)/290948635_T_ONTIME_REPORTING.csv')
# df_2020_october.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2020_october.to_csv (r'C:/Users/STSC/Desktop/Dataset/2020/october_2020.csv', index = False, header=True)

# %% [markdown]
# df_2011_november = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2011_november.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2011_november.to_csv (r'C:/Users/STSC/Desktop/Dataset/2011/november_2011.csv', index = False, header=True)
#
# df_2012_november = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2012_november.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2012_november.to_csv (r'C:/Users/STSC/Desktop/Dataset/2012/november_2012.csv', index = False, header=True)
#
# df_2013_november = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (3)/290948635_T_ONTIME_REPORTING.csv')
# df_2013_november.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2013_november.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/november_2013.csv', index = False, header=True)
#
# df_2014_november = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (4)/290948635_T_ONTIME_REPORTING.csv')
# df_2014_november.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2014_november.to_csv (r'C:/Users/STSC/Desktop/Dataset/2014/november_2014.csv', index = False, header=True)
#
# df_2015_november = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (5)/290948635_T_ONTIME_REPORTING.csv')
# df_2015_november.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2015_november.to_csv (r'C:/Users/STSC/Desktop/Dataset/2015/november_2015.csv', index = False, header=True)
#
# df_2016_november = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (6)/290948635_T_ONTIME_REPORTING.csv')
# df_2016_november.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2016_november.to_csv (r'C:/Users/STSC/Desktop/Dataset/2016/november_2016.csv', index = False, header=True)
#
# df_2017_november = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (7)/290948635_T_ONTIME_REPORTING.csv')
# df_2017_november.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2017_november.to_csv (r'C:/Users/STSC/Desktop/Dataset/2017/november_2017.csv', index = False, header=True)
#
# df_2018_november = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (8)/290948635_T_ONTIME_REPORTING.csv')
# df_2018_november.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2018_november.to_csv (r'C:/Users/STSC/Desktop/Dataset/2018/november_2018.csv', index = False, header=True)
#
# df_2019_november = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (9)/290948635_T_ONTIME_REPORTING.csv')
# df_2019_november.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2019_november.to_csv (r'C:/Users/STSC/Desktop/Dataset/2019/november_2019.csv', index = False, header=True)
#
# df_2020_november = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (10)/290948635_T_ONTIME_REPORTING.csv')
# df_2020_november.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2020_november.to_csv (r'C:/Users/STSC/Desktop/Dataset/2020/november_2020.csv', index = False, header=True)

# %% [markdown]
# df_2011_december = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (1)/290948635_T_ONTIME_REPORTING.csv')
# df_2011_december.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2011_december.to_csv (r'C:/Users/STSC/Desktop/Dataset/2011/december_2011.csv', index = False, header=True)
#
# df_2012_december = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (2)/290948635_T_ONTIME_REPORTING.csv')
# df_2012_december.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2012_december.to_csv (r'C:/Users/STSC/Desktop/Dataset/2012/december_2012.csv', index = False, header=True)
#
# df_2013_december = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (3)/290948635_T_ONTIME_REPORTING.csv')
# df_2013_december.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2013_december.to_csv (r'C:/Users/STSC/Desktop/Dataset/2013/december_2013.csv', index = False, header=True)
#
# df_2014_december = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (4)/290948635_T_ONTIME_REPORTING.csv')
# df_2014_december.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2014_december.to_csv (r'C:/Users/STSC/Desktop/Dataset/2014/december_2014.csv', index = False, header=True)
#
# df_2015_december = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (5)/290948635_T_ONTIME_REPORTING.csv')
# df_2015_december.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2015_december.to_csv (r'C:/Users/STSC/Desktop/Dataset/2015/december_2015.csv', index = False, header=True)
#
# df_2016_december = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (6)/290948635_T_ONTIME_REPORTING.csv')
# df_2016_december.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2016_december.to_csv (r'C:/Users/STSC/Desktop/Dataset/2016/december_2016.csv', index = False, header=True)
#
# df_2017_december = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (7)/290948635_T_ONTIME_REPORTING.csv')
# df_2017_december.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2017_december.to_csv (r'C:/Users/STSC/Desktop/Dataset/2017/december_2017.csv', index = False, header=True)
#
# df_2018_december = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (8)/290948635_T_ONTIME_REPORTING.csv')
# df_2018_december.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2018_december.to_csv (r'C:/Users/STSC/Desktop/Dataset/2018/december_2018.csv', index = False, header=True)
#
# df_2019_december = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (9)/290948635_T_ONTIME_REPORTING.csv')
# df_2019_december.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2019_december.to_csv (r'C:/Users/STSC/Desktop/Dataset/2019/december_2019.csv', index = False, header=True)
#
# df_2020_december = pd.read_csv(r'C:/Users/STSC/Downloads/290948635_T_ONTIME_REPORTING (10)/290948635_T_ONTIME_REPORTING.csv')
# df_2020_december.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2020_december.to_csv (r'C:/Users/STSC/Desktop/Dataset/2020/december_2020.csv', index = False, header=True)

# %% [markdown]
# df_2010_march = pd.read_csv(r'C:/Users/STSC/Downloads/290915200_T_ONTIME_REPORTING/290915200_T_ONTIME_REPORTING.csv')
# df_2010_march.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2010_march.to_csv (r'C:/Users/STSC/Desktop/Dataset/2010/march_2010.csv', index = False, header=True)

# %% [markdown]
# df_2010_april = pd.read_csv(r'C:/Users/STSC/Downloads/290915200_T_ONTIME_REPORTING/290915200_T_ONTIME_REPORTING.csv')
# df_2010_april.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2010_april.to_csv (r'C:/Users/STSC/Desktop/Dataset/2010/april_2010.csv', index = False, header=True)

# %% [markdown]
# df_2010_may = pd.read_csv(r'C:/Users/STSC/Downloads/290915200_T_ONTIME_REPORTING/290915200_T_ONTIME_REPORTING.csv')
# df_2010_may.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2010_may.to_csv (r'C:/Users/STSC/Desktop/Dataset/2010/may_2010.csv', index = False, header=True)

# %% [markdown]
# df_2010_june = pd.read_csv(r'C:/Users/STSC/Downloads/290915200_T_ONTIME_REPORTING/290915200_T_ONTIME_REPORTING.csv')
# df_2010_june.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2010_june.to_csv (r'C:/Users/STSC/Desktop/Dataset/2010/june_2010.csv', index = False, header=True)

# %% [markdown]
# df_2010_july = pd.read_csv(r'C:/Users/STSC/Downloads/290915200_T_ONTIME_REPORTING/290915200_T_ONTIME_REPORTING.csv')
# df_2010_july.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2010_july.to_csv (r'C:/Users/STSC/Desktop/Dataset/2010/july_2010.csv', index = False, header=True)

# %% [markdown]
# df_2010_august = pd.read_csv(r'C:/Users/STSC/Downloads/290915200_T_ONTIME_REPORTING/290915200_T_ONTIME_REPORTING.csv')
# df_2010_august.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2010_august.to_csv (r'C:/Users/STSC/Desktop/Dataset/2010/august_2010.csv', index = False, header=True)

# %% [markdown]
# df_2010_september = pd.read_csv(r'C:/Users/STSC/Downloads/290915200_T_ONTIME_REPORTING/290915200_T_ONTIME_REPORTING.csv')
# df_2010_september.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2010_september.to_csv (r'C:/Users/STSC/Desktop/Dataset/2010/september_2010.csv', index = False, header=True)

# %% [markdown]
# df_2010_october = pd.read_csv(r'C:/Users/STSC/Downloads/290915200_T_ONTIME_REPORTING/290915200_T_ONTIME_REPORTING.csv')
# df_2010_october.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2010_october.to_csv (r'C:/Users/STSC/Desktop/Dataset/2010/october_2010.csv', index = False, header=True)

# %% [markdown]
# df_2010_november = pd.read_csv(r'C:/Users/STSC/Downloads/290915200_T_ONTIME_REPORTING/290915200_T_ONTIME_REPORTING.csv')
# df_2010_november.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2010_november.to_csv (r'C:/Users/STSC/Desktop/Dataset/2010/november_2010.csv', index = False, header=True)

# %% [markdown]
# df_2010_december = pd.read_csv(r'C:/Users/STSC/Downloads/290915200_T_ONTIME_REPORTING/290915200_T_ONTIME_REPORTING.csv')
# df_2010_december.dropna(subset = ["CARRIER_DELAY"], inplace=True)
# df_2010_december.to_csv (r'C:/Users/STSC/Desktop/Dataset/2010/december_2010.csv', index = False, header=True)

# %% [markdown]
# ### Here I have combined the data of each year in one file and at the very end all the years together in one csv file.

# %%
import os
import glob

# %% [markdown]
# os.chdir("C:/Users/STSC/Desktop/Dataset/2010")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_2010_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# os.chdir("C:/Users/STSC/Desktop/Dataset/2011")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_2011_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# os.chdir("C:/Users/STSC/Desktop/Dataset/2012")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_2012_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# os.chdir("C:/Users/STSC/Desktop/Dataset/2013")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_2013_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# os.chdir("C:/Users/STSC/Desktop/Dataset/2014")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_2014_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# os.chdir("C:/Users/STSC/Desktop/Dataset/2015")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_2015_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# os.chdir("C:/Users/STSC/Desktop/Dataset/2016")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_2016_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# os.chdir("C:/Users/STSC/Desktop/Dataset/2017")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_2017_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# os.chdir("C:/Users/STSC/Desktop/Dataset/2018")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_2018_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# os.chdir("C:/Users/STSC/Desktop/Dataset/2019")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_2019_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# os.chdir("C:/Users/STSC/Desktop/Dataset/2020")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_20_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# ### This is the final dataset downloaded. You will find it uploaded in the shared Drive folder/ Github as well.

# %% [markdown]
# os.chdir("C:/Users/STSC/Desktop/Dataset/Combined")
# extension = 'csv'
# all_filenames = [i for i in glob.glob('*.{}'.format(extension))]
# #combine all files in the list
# combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
# #export to csv
# combined_csv.to_csv( "combined_2010-2020_csv.csv", index=False, encoding='utf-8-sig')

# %% [markdown]
# # Load the dataset and create a data frame

# %%
import pandas as pd

df_combined = pd.read_csv (r'C:/Users/STSC/Desktop/CAPSTONE Project/Dataset/Combined/combined_2010-2020_csv.csv')
print (df_combined)
# Out:
#           YEAR  MONTH  DAY_OF_MONTH OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0         2010      4            25                9E                  20363
# 1         2010      4             5                9E                  20363
# 2         2010      4             6                9E                  20363
# 3         2010      4             7                9E                  20363
# 4         2010      4             8                9E                  20363
# ...        ...    ...           ...               ...                    ...
# 11221075  2020      9             5                OO                  20304
# 11221076  2020      9             5                OO                  20304
# 11221077  2020      9             5                OO                  20304
# 11221078  2020      9             5                OO                  20304
# 11221079  2020      9             5                OO                  20304
#
# ...

# %% [markdown]
# # Import some libraries that I will need later on for data cleaning and some simple analysis of the dataset

# %%
import datetime, warnings, scipy
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import ConnectionPatch
from collections import OrderedDict
from matplotlib.gridspec import GridSpec

from sklearn import metrics, linear_model
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict
from scipy.optimize import curve_fit
plt.rcParams["patch.force_edgecolor"] = True
plt.style.use('fivethirtyeight')
mpl.rc('patch', edgecolor = 'dimgray', linewidth=1)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"
pd.options.display.max_columns = 50
# %matplotlib inline
warnings.filterwarnings("ignore")

# %% [markdown]
# # Get some informations on columns types and number of null values

# %%
tab_info=pd.DataFrame(df_combined.dtypes).T.rename(index={0:'column type'})
tab_info=tab_info.append(pd.DataFrame(df_combined.isnull().sum()).T.rename(index={0:'null values (nb)'}))
tab_info=tab_info.append(pd.DataFrame(df_combined.isnull().sum()/df_combined.shape[0]*100)
                         .T.rename(index={0:'null values (%)'}))
tab_info
# Out:
#                    YEAR  MONTH DAY_OF_MONTH OP_UNIQUE_CARRIER  \
# column type       int64  int64        int64            object
# null values (nb)      0      0            0                 0
# null values (%)     0.0    0.0          0.0               0.0
#
#                  OP_CARRIER_AIRLINE_ID OP_CARRIER TAIL_NUM OP_CARRIER_FL_NUM  \
# column type                      int64     object   object             int64
# null values (nb)                     0          0        0                 0
# null values (%)                    0.0        0.0      0.0               0.0
#
#                  ORIGIN_AIRPORT_ID ORIGIN_AIRPORT_SEQ_ID  \
# column type                  int64                 int64
# null values (nb)                 0                     0
# null values (%)                0.0                   0.0
#
#                  ORIGIN_CITY_MARKET_ID  ORIGIN ORIGIN_CITY_NAME  \
# column type                      int64  object           object
# ...

# %% [markdown]
# # Dates and times
#
# #### The date column is splitet in three. We will need a single column for the full date in datetime format. This is what I am doing below.

# %%
df_combined['DAY'] = df_combined['DAY_OF_MONTH']
df_combined['DAY'] = df_combined.loc[:, 'DAY_OF_MONTH']

# %%
df_combined.head()
# Out:
#    YEAR  MONTH  DAY_OF_MONTH OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID  \
# 0  2010      4            25                9E                  20363
# 1  2010      4             5                9E                  20363
# 2  2010      4             6                9E                  20363
# 3  2010      4             7                9E                  20363
# 4  2010      4             8                9E                  20363
#
#   OP_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  \
# 0         9E   86239E               4093              15249
# 1         9E   85329E               4094              11433
# 2         9E   80299E               4094              15380
# 3         9E   89139E               4094              15380
# 4         9E   86319E               4094              15380
#
#    ORIGIN_AIRPORT_SEQ_ID  ORIGIN_CITY_MARKET_ID ORIGIN   ORIGIN_CITY_NAME  \
# 0                1524901                  35249    TLH    Tallahassee, FL
# ...

# %%
pip install dataframe-image
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: pandas>=0.24 in c:\users\stsc\anaconda3\envs\tensorflow1\lib\site-packages (from dataframe-image) (1.3.2)
# ...
#
# ...

# %% [markdown]
# #### Getting a sample of the dataset for documentation purposes

# %%
import dataframe_image as dfi

# %%
df_image=df_combined.sample(n=8)
df_image
# Out:
#          YEAR  MONTH OP_UNIQUE_CARRIER  OP_CARRIER_AIRLINE_ID OP_CARRIER  \
# 4641250  2014      3                US                  20355         US
# 9501091  2019      8                AA                  19805         AA
# 5936329  2015      5                WN                  19393         WN
# 1483900  2010      2                MQ                  20398         MQ
# 489679   2010      1                XE                  20374         XE
# 7536055  2017      7                WN                  19393         WN
# 7517615  2017      7                EV                  20366         EV
# 6972732  2016     11                B6                  20409         B6
#
#         TAIL_NUM  OP_CARRIER_FL_NUM  ORIGIN_AIRPORT_ID  ORIGIN_AIRPORT_SEQ_ID  \
# 4641250   N657AW                687              14107                1410702
# 9501091   N534UW               2511              12892                1289208
# ...

# %%
dfi.export(df_image, 'df_styled.png', max_cols=10)

# %% [markdown]
# In the initial dataframe, dates are coded according to 3 variables: YEAR, MONTH, and DAY_OF_MONTH. In fact, python offers the datetime format which is really convenient to work with dates and times and I thus convert the dates in this format

# %%
df_combined = df_combined.drop(['DAY_OF_MONTH'], axis = 1)

# %%
df_combined['DATE'] = pd.to_datetime(df_combined[['YEAR','MONTH', 'DAY']])

# %%
#_________________________________________________________
# Function that convert the 'HHMM' string to datetime.time
def format_heure(chaine):
    if pd.isnull(chaine):
        return np.nan
    else:
        if chaine == 2400: chaine = 0
        chaine = "{0:04d}".format(int(chaine))
        heure = datetime.time(int(chaine[0:2]), int(chaine[2:4]))
        return heure
#_____________________________________________________________________
# Function that combines a date and time to produce a datetime.datetime
def combine_date_heure(x):
    if pd.isnull(x[0]) or pd.isnull(x[1]):
        return np.nan
    else:
        return datetime.datetime.combine(x[0],x[1])
#_______________________________________________________________________________
# Function that combine two columns of the dataframe to create a datetime format
def create_flight_time(df, col):
    liste = []
    for index, cols in df_combined[['DATE', col]].iterrows():
        if pd.isnull(cols[1]):
            liste.append(np.nan)
        elif float(cols[1]) == 2400:
            cols[0] += datetime.timedelta(days=1)
            cols[1] = datetime.time(0,0)
            liste.append(combine_date_heure(cols))
        else:
            cols[1] = format_heure(cols[1])
            liste.append(combine_date_heure(cols))
    return pd.Series(liste)

# %%
# and I call them to modify the dataframe variables:

df_combined['CRS_DEP_TIME'] = create_flight_time(df_combined, 'CRS_DEP_TIME')
df_combined['DEP_TIME'] = df_combined['DEP_TIME'].apply(format_heure)
df_combined['CRS_ARR_TIME'] = df_combined['CRS_ARR_TIME'].apply(format_heure)
df_combined['ARR_TIME'] = df_combined['ARR_TIME'].apply(format_heure)
#__________________________________________________________________________
df_combined.loc[:5, ['CRS_DEP_TIME', 'CRS_ARR_TIME', 'DEP_TIME',
             'ARR_TIME', 'DEP_DELAY', 'ARR_DELAY']]
# Out:
#          CRS_DEP_TIME CRS_ARR_TIME  DEP_TIME  ARR_TIME  DEP_DELAY  ARR_DELAY
# 0 2010-04-25 12:20:00     12:56:00  12:28:00  13:31:00        8.0       35.0
# 1 2010-04-05 19:35:00     20:56:00  19:34:00  21:20:00       -1.0       24.0
# 2 2010-04-06 17:20:00     18:25:00  17:37:00  18:45:00       17.0       20.0
# 3 2010-04-07 17:20:00     18:25:00  17:21:00  18:49:00        1.0       24.0
# 4 2010-04-08 17:20:00     18:25:00  17:09:00  18:49:00      -11.0       24.0
# 5 2010-04-09 17:20:00     18:25:00  19:09:00  20:04:00      109.0       99.0

# %% [markdown]
# Note that in practice, the content of the DEP_TIME and ARR_TIME variables can be a bit misleading since they don't contain the dates. So,we don't know if the flight left before time or if there was a large delay. Hence, the DEP_DELAY and ARR_DELAY variables prove more useful since they directly provide the delays in minutes. Hence, in what follows, I will use the DEP_TIME and ARR_TIME variables.

# %%
df_combined.loc[:5, ['CRS_DEP_TIME', 'CRS_ARR_TIME', 'DEP_TIME',
             'ARR_TIME', 'DEP_DELAY', 'ARR_DELAY']].to_csv('out.csv')

# %%
df_combined.shape
# Out:
# (11221080, 52)

# %% [markdown]
# # Examine how complete the dataset is and the columns that have missing values

# %%
missing_df = df_combined.isnull().sum(axis=0).reset_index()
missing_df.columns = ['variable', 'missing values']
missing_df['filling factor (%)']=(df_combined.shape[0]-missing_df['missing values'])/df_combined.shape[0]*100
missing_df.sort_values('filling factor (%)').reset_index(drop = True)
# Out:
#                    variable  missing values  filling factor (%)
# 0               Unnamed: 50        11221080            0.000000
# 1              DIV_DISTANCE        11221080            0.000000
# 2             DIV_ARR_DELAY        11221080            0.000000
# 3   DIV_ACTUAL_ELAPSED_TIME        11221080            0.000000
# 4          DIV_REACHED_DEST        11221080            0.000000
# 5         CANCELLATION_CODE        11221080            0.000000
# 6                 DEP_DEL15             301           99.997318
# 7             DEP_DELAY_NEW             301           99.997318
# 8                 DEP_DELAY             301           99.997318
# 9          CRS_ELAPSED_TIME               3           99.999973
# 10             CRS_ARR_TIME               3           99.999973
# 11             CRS_DEP_TIME               2           99.999982
# 12            DEST_STATE_NM               1           99.999991
# 13                 ARR_TIME               1           99.999991
# ...

# %%
## for word documentation purposes
missing_df.sort_values('filling factor (%)').reset_index(drop = True).to_csv('out2.csv')

# %% [markdown]
# ### Remove those columns that have olny missing valuse

# %%
df_combined = df_combined.drop(['DIV_DISTANCE','DIV_ARR_DELAY', 'DIV_ACTUAL_ELAPSED_TIME', 'DIV_REACHED_DEST', 'CANCELLATION_CODE'], axis=1)

# %% [markdown]
# # Comparing Airlines

# %% [markdown]
# The AIRLINE variable contains the airline abreviations. Their full names can be retrieved from the Airlines1.csv file.

# %%
## find the number of unique origin airports

print("Nb of airports: {}".format(len(df_combined['ORIGIN_AIRPORT_ID'].unique())))
# Out:
# Nb of airports: 389

# %% [markdown]
# Here, I have a quick look at the number of destination airports for each airline:

# %%
airlines_names = pd.read_csv(r'C:/Users/STSC/Desktop/CAPSTONE Project/Airlines1.csv')
airlines_names
# Out:
#    Code                  Description
# 0    9E            Endeavor Air Inc.
# 1    AA       American Airlines Inc.
# 2    CO   Continental Air Lines Inc.
# 3    DL         Delta Air Lines Inc.
# 4    EV      ExpressJet Airlines LLC
# 5    F9       Frontier Airlines Inc.
# 6    FL  AirTran Airways Corporation
# 7    MQ                    Envoy Air
# 8    OO        SkyWest Airlines Inc.
# 9    UA        United Air Lines Inc.
# 10   US              US Airways Inc.
# 11   WN       Southwest Airlines Co.
# 12   XE     ExpressJet Airlines Inc.
# 13   YV           Mesa Airlines Inc.
# 14   AS         Alaska Airlines Inc.
# 15   B6              JetBlue Airways
# 16   HA       Hawaiian Airlines Inc.
# 17   OH            PSA Airlines Inc.
# 18   VX               Virgin America
# 19   NK             Spirit Air Lines
# 20   G4                Allegiant Air
# 21   YX             Republic Airline

# %%
#For further use, I put the content of this this dataframe in a dictionary:

abbr_companies = airlines_names.set_index('Code')['Description'].to_dict()

# %%
abbr_companies
# Out:
# {'9E': 'Endeavor Air Inc.',
#  'AA': 'American Airlines Inc.',
#  'CO': 'Continental Air Lines Inc.',
#  'DL': 'Delta Air Lines Inc.',
#  'EV': 'ExpressJet Airlines LLC',
#  'F9': 'Frontier Airlines Inc.',
#  'FL': 'AirTran Airways Corporation',
#  'MQ': 'Envoy Air',
#  'OO': 'SkyWest Airlines Inc.',
#  'UA': 'United Air Lines Inc.',
#  'US': 'US Airways Inc.',
#  'WN': 'Southwest Airlines Co.',
#  'XE': 'ExpressJet Airlines Inc.',
#  'YV': 'Mesa Airlines Inc.',
#  'AS': 'Alaska Airlines Inc.',
#  'B6': 'JetBlue Airways',
#  'HA': 'Hawaiian Airlines Inc.',
#  'OH': 'PSA Airlines Inc.',
#  'VX': 'Virgin America',
#  'NK': 'Spirit Air Lines',
#  'G4': 'Allegiant Air',
#  'YX': 'Republic Airline'}

# %%
df_combined.OP_UNIQUE_CARRIER.unique()
# Out:
# array(['9E', 'AA', 'CO', 'DL', 'EV', 'F9', 'FL', 'MQ', 'OO', 'UA', 'US',
#        'WN', 'XE', 'YV', 'AS', 'B6', 'HA', 'OH', 'VX', 'NK', 'G4', 'YX'],
#       dtype=object)

# %% [markdown]
# # Basic statistical description of airlines

# %% [markdown]
# As a first step, I consider all the flights from all carriers. Here, the aim is to classify the airlines with respect to their punctuality and for that purpose, I compute a few basic statisticial parameters

# %%
#__________________________________________________________________
# function that extract statistical parameters from a grouby objet:
def get_stats(group):
    return {'min': group.min(), 'max': group.max(),
            'count': group.count(), 'mean': group.mean()}
#_______________________________________________________________
# Creation of a dataframe with statitical infos on each airline:
global_stats = df_combined['DEP_DELAY'].groupby(df_combined['OP_UNIQUE_CARRIER']).apply(get_stats).unstack()
global_stats = global_stats.sort_values('count')
global_stats
# Out:
#                     min     max      count       mean
# OP_UNIQUE_CARRIER
# G4                -37.0  1979.0    55023.0  68.086364
# HA                -22.0  2482.0    67546.0  34.704646
# VX                -22.0   705.0    72220.0  54.194628
# CO                -22.0  1170.0    94496.0  41.271419
# FL                -20.0   811.0   131417.0  46.081473
# YX                -30.0  1377.0   134337.0  57.766542
# 9E                -46.0  2579.0   159762.0  63.113018
# XE                -22.0   898.0   165250.0  51.976563
# OH                -26.0  1919.0   166891.0  60.255029
# NK                -47.0  1634.0   179885.0  62.826061
# YV                -34.0  2209.0   181804.0  62.858919
# F9                -32.0  1112.0   221544.0  57.697852
# AS                -51.0  1117.0   251842.0  40.661494
# US                -25.0   981.0   326816.0  37.138892
# B6                -28.0  1769.0   593532.0  61.799421
# MQ                -29.0  2672.0   600932.0  49.965810
# ...

# %% [markdown]
# Now, in order to facilitate the lecture of that information, I construct some graphics:

# %%
origin_nb = dict()
for carrier in abbr_companies.keys():
    liste_origin_airport = df_combined[df_combined['OP_CARRIER_AIRLINE_ID'] == carrier]['ORIGIN_AIRPORT_ID'].unique()
    origin_nb[carrier] = len(liste_origin_airport)

# %%
font = {'family' : 'normal', 'weight' : 'bold', 'size'   : 15}
mpl.rc('font', **font)
import matplotlib.patches as mpatches
#__________________________________________________________________
# I extract a subset of columns and redefine the airlines labeling
df2 = df_combined.loc[:, ['OP_UNIQUE_CARRIER', 'DEP_DELAY']]
df2['OP_UNIQUE_CARRIER'] = df2['OP_UNIQUE_CARRIER'].replace(abbr_companies)
#________________________________________________________________________
colors = ['royalblue', 'grey', 'wheat', 'c', 'firebrick', 'seagreen', 'lightskyblue',
          'lightcoral', 'yellowgreen', 'gold', 'tomato', 'violet', 'aquamarine', 'chartreuse', 'rosybrown', 'olive', 'cyan', 'lime', 'mediumpurple', 'goldenrod', 'lightblue', 'indigo']
#___________________________________
fig = plt.figure(1, figsize=(16,15))
gs=GridSpec(2,2)
ax1=fig.add_subplot(gs[0,0])
ax2=fig.add_subplot(gs[0,1])
ax3=fig.add_subplot(gs[1,:])
#------------------------------
# Pie chart nº1: nb of flights
#------------------------------
labels = [s for s in  global_stats.index]
sizes  = global_stats['count'].values
explode = None
patches, texts, autotexts = ax1.pie(sizes, explode = explode,
                                labels=labels, colors = colors,  autopct='%1.0f%%',
                                shadow=False, startangle=0)
for i in range(len(abbr_companies)):
    texts[i].set_fontsize(14)
ax1.axis('equal')
ax1.set_title('% of flights per company', bbox={'facecolor':'midnightblue', 'pad':5},
              color = 'w',fontsize=18)
#_______________________________________________
# I set the legend: abreviation -> airline name
comp_handler = []
for i in range(len(abbr_companies)):
    comp_handler.append(mpatches.Patch(color=colors[i],
            label = global_stats.index[i] + ': ' + abbr_companies[global_stats.index[i]]))
ax1.legend(handles=comp_handler, bbox_to_anchor=(0.2, 0.9),
           fontsize = 13, bbox_transform=plt.gcf().transFigure)
#----------------------------------------
# Pie chart nº2: mean delay at departure
#----------------------------------------
sizes  = global_stats['mean'].values
sizes  = [max(s,0) for s in sizes]
explode = [0.3 if sizes[i] < 20000 else 0.01 for i in range(len(abbr_companies))]
patches, texts, autotexts = ax2.pie(sizes, explode = explode, labels = labels,
                                colors = colors, shadow=False, startangle=0,
                                autopct = lambda p :  '{:.0f}'.format(p * sum(sizes) / 100))
for i in range(len(abbr_companies)):
    texts[i].set_fontsize(14)
ax2.axis('equal')
ax2.set_title('Mean delay at origin', bbox={'facecolor':'midnightblue', 'pad':5},
              color='w', fontsize=18)
#------------------------------------------------------
# striplot with all the values reported for the delays
#___________________________________________________________________
# I redefine the colors for correspondance with the pie charts
colors = ['royalblue', 'grey', 'wheat', 'c', 'firebrick', 'seagreen', 'lightskyblue',
          'lightcoral', 'yellowgreen', 'gold', 'tomato', 'violet', 'aquamarine', 'chartreuse', 'rosybrown', 'olive', 'cyan', 'lime', 'mediumpurple', 'goldenrod', 'lightblue', 'indigo']
#___________________________________________________________________
ax3 = sns.stripplot(y="OP_UNIQUE_CARRIER", x="DEP_DELAY", size = 4, palette = colors,
                    data=df2, linewidth = 0.5,  jitter=True)
plt.setp(ax3.get_xticklabels(), fontsize=14)
plt.setp(ax3.get_yticklabels(), fontsize=14)
ax3.set_xticklabels(['{:2.0f}h{:2.0f}m'.format(*[int(y) for y in divmod(x,60)])
                         for x in ax3.get_xticks()])
plt.xlabel('Departure delay', fontsize=18, bbox={'facecolor':'midnightblue', 'pad':5},
           color='w', labelpad=20)
ax3.yaxis.label.set_visible(False)
#________________________
plt.tight_layout(w_pad=3)

# %% [markdown]
# Considering the first pie chart that gives the percentage of flights per airline, we see that there is some disparity between the carriers. For exemple, (WN) Southwest Airlines accounts for  ∼ 20% of the flights which is similar to the number of flights chartered by the 7 tiniest airlines. However, if we have a look at the second pie chart, we see that here, on the contrary, the differences among airlines are less pronounced. Excluding Hawaiian Airlines and US Airways that report extremely low mean delays, we obtain that a value of  ∼ 35 ± 38 minutes would correctly represent all mean delays. Note that this value is quite high which mean that the standard for every airline is to respect the schedule needs to be improved ! I would still consider here the fact that the time frame we are analyzing is pretty wide. To make sure about the conclusions we shouls dig deeper and observe every year separately.
#
# Finally, the figure at the bottom makes a census of all the delays that were measured from 2010 to 2020. This representation gives a feeling on the dispersion of data and put in perspective the relative homogeneity that appeared in the second pie chart. Indeed, we see that while all mean delays are around 60 minutes, this low value is a consequence of the fact that a majority of flights take off on time. However, we see that occasionally, we can face really large delays that can reach a few tens of hours!
# Again the wide range of years affect this analysis.

# %% [markdown]
# # Delays: take-off or landing ?

# %% [markdown]
# In the previous section, all the discussion was done on departure delays. However, these delays differ somewhat from the delays recorded at arrival

# %%
df_combined.OP_CARRIER.unique()
# Out:
# array(['9E', 'AA', 'CO', 'DL', 'EV', 'F9', 'FL', 'MQ', 'OO', 'UA', 'US',
#        'WN', 'XE', 'YV', 'AS', 'B6', 'HA', 'OH', 'VX', 'NK', 'G4', 'YX'],
#       dtype=object)

# %%
airlines_names = pd.read_csv('C:/Users/STSC/Desktop/CAPSTONE Project/Airlines1.csv')
airlines_names
# Out:
#    Code                  Description
# 0    9E            Endeavor Air Inc.
# 1    AA       American Airlines Inc.
# 2    CO   Continental Air Lines Inc.
# 3    DL         Delta Air Lines Inc.
# 4    EV      ExpressJet Airlines LLC
# 5    F9       Frontier Airlines Inc.
# 6    FL  AirTran Airways Corporation
# 7    MQ                    Envoy Air
# 8    OO        SkyWest Airlines Inc.
# 9    UA        United Air Lines Inc.
# 10   US              US Airways Inc.
# 11   WN       Southwest Airlines Co.
# 12   XE     ExpressJet Airlines Inc.
# 13   YV           Mesa Airlines Inc.
# 14   AS         Alaska Airlines Inc.
# 15   B6              JetBlue Airways
# 16   HA       Hawaiian Airlines Inc.
# 17   OH            PSA Airlines Inc.
# 18   VX               Virgin America
# 19   NK             Spirit Air Lines
# 20   G4                Allegiant Air
# 21   YX             Republic Airline

# %%
abbr_companies = airlines_names.set_index('Code')['Description'].to_dict()
print(abbr_companies)
# Out:
# {'9E': 'Endeavor Air Inc.', 'AA': 'American Airlines Inc.', 'CO': 'Continental Air Lines Inc.', 'DL': 'Delta Air Lines Inc.', 'EV': 'ExpressJet Airlines LLC', 'F9': 'Frontier Airlines Inc.', 'FL': 'AirTran Airways Corporation', 'MQ': 'Envoy Air', 'OO': 'SkyWest Airlines Inc.', 'UA': 'United Air Lines Inc.', 'US': 'US Airways Inc.', 'WN': 'Southwest Airlines Co.', 'XE': 'ExpressJet Airlines Inc.', 'YV': 'Mesa Airlines Inc.', 'AS': 'Alaska Airlines Inc.', 'B6': 'JetBlue Airways', 'HA': 'Hawaiian Airlines Inc.', 'OH': 'PSA Airlines Inc.', 'VX': 'Virgin America', 'NK': 'Spirit Air Lines', 'G4': 'Allegiant Air', 'YX': 'Republic Airline'}

# %%
mpl.rcParams.update(mpl.rcParamsDefault)
mpl.rcParams['hatch.linewidth'] = 2.0

fig = plt.figure(1, figsize=(11,6))
ax = sns.barplot(x="DEP_DELAY", y="OP_UNIQUE_CARRIER", data=df_combined, color="lightskyblue", ci=None)
ax = sns.barplot(x="ARR_DELAY", y="OP_UNIQUE_CARRIER", data=df_combined, color="r", hatch = '///',
                 alpha = 0.0, ci=None)
labels = [abbr_companies[item.get_text()] for item in ax.get_yticklabels()]
ax.set_yticklabels(labels)
ax.yaxis.label.set_visible(False)
plt.xlabel('Mean delay [min] (@departure: blue, @arrival: hatch lines)',
           fontsize=14, weight = 'bold', labelpad=10);

# %% [markdown]
# On this figure, we can see that delays at arrival are generally lower than at departure. This indicates that airlines adjust their flight speed in order to reduce the delays at arrival. In what follows, I will just consider the delays at departure but one has to keep in mind that this can differ from arrival delays.

# %% [markdown]
# # Relation between the origin airport and delays

# %% [markdown]
# I will now try to define if there is a correlation between the delays registered and the airport of origin. I recall that in the dataset, the number of airports considered is:

# %%
print("Nb of airports: {}".format(len(df_combined['ORIGIN_AIRPORT_ID'].unique())))
# Out:
# Nb of airports: 389

# %% [markdown]
# ## Geographical area covered by airlines

# %%
origin_nb = dict()
for carrier in abbr_companies.keys():
    #print(carrier)
    liste_origin_airport = df_combined[df_combined['OP_UNIQUE_CARRIER'] == carrier]['ORIGIN_AIRPORT_ID'].unique()
    origin_nb[carrier] = len(liste_origin_airport)

# %%
test_df = pd.DataFrame.from_dict(origin_nb, orient='index')
test_df.rename(columns = {0:'count'}, inplace = True)
ax = test_df.plot(kind='bar', figsize = (8,3))
labels = [abbr_companies[item.get_text()] for item in ax.get_xticklabels()]
ax.set_xticklabels(labels)
plt.ylabel('Number of airports visited', fontsize=14, weight = 'bold', labelpad=12)
plt.setp(ax.get_xticklabels(), fontsize=11, ha = 'right', rotation = 80)
ax.legend().set_visible(False)
plt.show()

# %% [markdown]
# ## How the origin airport impact delays

# %% [markdown]
# In this section, I will have a look at the variations of the delays with respect to the origin airport and for every airline. The first step thus consists in determining the mean delays per airport:

# %%
#__________________________________________________________________
# function that extract statistical parameters from a grouby objet:
def get_stats(group):
    return {'min': group.min(), 'max': group.max(),
            'count': group.count(), 'mean': group.mean()}
#_______________________________________________________________
# Creation of a dataframe with statitical infos on each airline:
global_stats = df_combined['DEP_DELAY'].groupby(df_combined['OP_UNIQUE_CARRIER']).apply(get_stats).unstack()
global_stats = global_stats.sort_values('count')
global_stats
# Out:
#                     min     max      count       mean
# OP_UNIQUE_CARRIER
# G4                -37.0  1979.0    55023.0  68.086364
# HA                -22.0  2482.0    67546.0  34.704646
# VX                -22.0   705.0    72220.0  54.194628
# CO                -22.0  1170.0    94496.0  41.271419
# FL                -20.0   811.0   131417.0  46.081473
# YX                -30.0  1377.0   134337.0  57.766542
# 9E                -46.0  2579.0   159762.0  63.113018
# XE                -22.0   898.0   165250.0  51.976563
# OH                -26.0  1919.0   166891.0  60.255029
# NK                -47.0  1634.0   179885.0  62.826061
# YV                -34.0  2209.0   181804.0  62.858919
# F9                -32.0  1112.0   221544.0  57.697852
# AS                -51.0  1117.0   251842.0  40.661494
# US                -25.0   981.0   326816.0  37.138892
# B6                -28.0  1769.0   593532.0  61.799421
# MQ                -29.0  2672.0   600932.0  49.965810
# ...

# %%
airport_mean_delays = pd.DataFrame(pd.Series(df_combined['ORIGIN_STATE_NM'].unique()))
airport_mean_delays.set_index(0, drop = True, inplace = True)

for carrier in abbr_companies.keys():
    df1 = df_combined[df_combined['OP_UNIQUE_CARRIER'] == carrier]
    test = df1['DEP_DELAY'].groupby(df_combined['ORIGIN_STATE_NM']).apply(get_stats).unstack()
    airport_mean_delays[carrier] = test.loc[:, 'mean']

# %% [markdown]
# Since the number of airports is quite large, a graph showing all the information at once would be a bit messy, since it would represent around 4400 values (i.e. 386 airports  ×  22 airlines). Hence, I just represent a subset of the data:

# %%
df0=pd.DataFrame(df_combined.ORIGIN_AIRPORT_ID.unique())

# %%
print(df0)
# Out:
#          0
# 0    15249
# 1    11433
# 2    15380
# 3    11042
# 4    13184
# ..     ...
# 384  14534
# 385  12365
# 386  12559
# 387  15569
# 388  10272
#
# [389 rows x 1 columns]

# %%
df0.to_csv('airports11.csv', index=False)

# %%
temp = pd.read_csv('C:/Users/STSC/Downloads/L_AIRPORT.csv')
identify_airport = temp.set_index('Code')['Description'].to_dict()

# %% [markdown]
# identify_airport = temp.set_index('ID')['Origin airport name'].to_dict()

# %%
sns.set(context="paper")
fig = plt.figure(1, figsize=(8,8))

ax = fig.add_subplot(1,2,1)
subset = airport_mean_delays.iloc[:50,:].rename(columns = abbr_companies)
subset = subset.rename(index = identify_airport)
mask = subset.isnull()
sns.heatmap(subset, linewidths=0.01, cmap="Accent", mask=mask, vmin = 0, vmax = 70)
plt.setp(ax.get_xticklabels(), fontsize=10, rotation = 85) ;
ax.yaxis.label.set_visible(False)

ax = fig.add_subplot(1,2,2)
subset = airport_mean_delays.iloc[:50,:].rename(columns = abbr_companies)
subset = subset.rename(index = identify_airport)
fig.text(0.5, 1.02, "Delays: impact of the origin airport", ha='center', fontsize = 18)
mask = subset.isnull()
sns.heatmap(subset, linewidths=0.01, cmap="Accent", mask=mask, vmin = 0, vmax = 70)
plt.setp(ax.get_xticklabels(), fontsize=10, rotation = 85) ;
ax.yaxis.label.set_visible(False)

plt.tight_layout()

# %% [markdown]
# This figure allows to draw some conclusions. First, by looking at the data associated with the different airlines, we find the behavior we previously observed: for example, if we consider the right panel, it will be seen that the column associated with ExpressJet Airlines LLC. mostly reports large delays, while the column associated with US Airways Inc. is mainly associated with delays of less than 35 minutes. If we now look at the airports of origin, we will see that some airports favor late departures: see e.g. Florida, Pennsylvania or Georgia.
#
# Finally, we can deduce from these observations that there is a high variability in average delays, both between the different airports but also between the different airlines.
